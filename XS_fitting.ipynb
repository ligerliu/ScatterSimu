# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import json
Ibeta = json.load(open('/Users/jiliangliu/Downloads/Ibeta.json'))
Ibeta.update(name='Ibeta')
Ialpha = json.load(open('/Users/jiliangliu/Downloads/Ialpha.json'))
Ialpha.update(name='Ialpha')

# %%
Ialpha1 = {}
Ialpha1.update(Ialpha)
Ialpha1.update(a=Ialpha['b'])
Ialpha1.update(b=Ialpha['c'])
Ialpha1.update(c=Ialpha['a'])
Ialpha1.update(alpha=Ialpha['beta'])
Ialpha1.update(beta=Ialpha['gamma'])
Ialpha1.update(gamma=Ialpha['alpha'])
Ialpha1.update(fract_x=Ialpha['fract_y'])
Ialpha1.update(fract_y=Ialpha['fract_z'])
Ialpha1.update(fract_z=Ialpha['fract_x'])
#Ialpha = Ialpha1

# %%
# %run -i NanoParticle.py
#from NanoParticle import cellulose_layline
q = np.linspace(0.01,2.3,2000)
qr = np.linspace(0.01,2.3,2000)
sigma = 0.002
h = 5
k = 5
l = 5
S  = cellulose_structure_factor(q,h,k,l,Ialpha1,sigma)/2.
S1 = cellulose_structure_factor(q,h,k,l,Ibeta,sigma)
S2 = cellulose_layer_line(qr,h,k,0,Ialpha1,sigma)/2.
S4 = cellulose_layer_line(qr,h,k,0,Ibeta,sigma)
#Ialpha

# %%
plt.subplots()
plt.plot(qr,S/np.max(S),qr,S1/np.max(S1))
plt.ylim(-0.1,1.1)
plt.title('powder pattern')
plt.legend([r'$I_{\beta}$',r'$I_{\alpha}$'])
plt.xlabel(r'$q\,\,(\AA^{-1})$')
plt.subplots()
plt.plot(qr,S2/np.max(S2),qr,S4/np.max(S4))
plt.title('layerline 0')
plt.legend([r'$I_{\beta}$',r'$I_{\alpha}$'])
plt.xlabel(r'$q\,\,(\AA^{-1})$')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, '$q\\,\\,(\\AA^{-1})$')

# %%
data = np.loadtxt('/Users/jiliangliu/Downloads/yill.xye',skiprows=1)

# %%
q = 2*np.sin(np.radians(data[:,0])/2)/1.546*2*np.pi
S = cellulose_structure_factor(q,h,k,l,Ibeta,sigma*50)
S1 = cellulose_structure_factor(q,h,k,l,Ibeta,sigma*120)
S2 = cellulose_structure_factor(q,h,k,l,Ialpha1,sigma)

# %%
plt.subplots()
plt.plot(q,data[:,1]/np.max(data[:,1]),q,S/np.max(S)*.8,q,S1/np.max(S1[q>0.5])*.2,
        q,S/np.max(S)*.8+S1/np.max(S1[q>0.5])*.2)#,q,S2/np.max(S2[q>0.5]))
plt.ylim(-0.1,1.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-0.1, 1.1)

# %%
sigma = 0.2
sigma1 = 0.08
h = 5
k = 5
l = 5
SA0 = cellulose_layer_line(qr,h,k,0,Ialpha1,sigma)
SB0 = cellulose_layer_line(qr,h,k,0,Ibeta,sigma1)/4.
SA1 = cellulose_layer_line(qr,h,k,1,Ialpha1,sigma)
SB1 = cellulose_layer_line(qr,h,k,1,Ibeta,sigma1)/4.
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.plot(qr,SA0,qr,SB0)
plt.legend(['Ialpha','Ibeta'])
plt.title('l=0')
plt.ylim(-100,15000)
plt.subplot(122)
plt.plot(qr,SA1,qr,SB1)
plt.legend(['Ialpha','Ibeta'])
plt.title('l=1')
plt.ylim(-100,2000)

SA2 = cellulose_layer_line(qr,h,k,2,Ialpha1,sigma)
SB2 = cellulose_layer_line(qr,h,k,2,Ibeta,sigma1)/4.
SA3 = cellulose_layer_line(qr,h,k,3,Ialpha1,sigma)
SB3 = cellulose_layer_line(qr,h,k,3,Ibeta,sigma1)/4.
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.plot(qr,SA2,qr,SB2)
plt.legend(['Ialpha','Ibeta'])
plt.title('l=2')
plt.ylim(-100,2000)
plt.subplot(122)
plt.plot(qr,SA3,qr,SB3)
plt.legend(['Ialpha','Ibeta'])
plt.title('l=3')
plt.ylim(-100,2000)

SA3 = cellulose_layer_line(qr,h,k,3,Ialpha1,sigma)
SB3 = cellulose_layer_line(qr,h,k,3,Ibeta,sigma1)/4.
SA4 = cellulose_layer_line(qr,h,k,4,Ialpha1,sigma)
SB4 = cellulose_layer_line(qr,h,k,4,Ibeta,sigma1)/4.
plt.figure(figsize=(10,4))
plt.subplot(121)
plt.plot(qr,SA3,qr,SB3)
plt.legend(['Ialpha','Ibeta'])
plt.title('l=3')
plt.ylim(-100,2000)
plt.subplot(122)
plt.plot(qr,SA4,qr,SB4)
plt.legend(['Ialpha','Ibeta'])
plt.title('l=4')
plt.ylim(-100,2000)
#plt.subplots()
#plt.plot(qr,SB2/np.max(SB2[100:]),qr,SB4/np.max(SB4[100:]))
#plt.ylim(-0.1,1.1)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# (-100, 2000)

# %%
# %run -i NanoParticle.py
qx,qz = np.meshgrid(np.linspace(-3,3,100),np.linspace(-3,3,100))
qy = np.zeros(qx.shape)
plt.figure(figsize=(10,4))
plt.subplot(131)
plt.imshow(np.log(np.abs(box_form_factor(np.array([qx,qy,qz]),10,3,10,4))+1),vmin=0,vmax =5,cmap='jet')
plt.title('x-z plane')
qr,qz = np.meshgrid(np.linspace(-3,3,100),np.linspace(-3,3,100))
f_cly_ave = np.zeros(qr.shape)
V_ave = np.zeros(qr.shape)
for theta in np.linspace(0,2*np.pi,360):
    qx = qr*np.cos(theta)
    qy = qr*np.sin(theta)
    f_cly_ave += np.abs(box_form_factor(np.array([qx,qy,qz]),10,3,10,4))*2*np.pi/360
    V_ave += 2*np.pi/360
f_cly_ave /= V_ave
plt.subplot(132)
plt.imshow(np.log(f_cly_ave+1),vmin=0,vmax =5, cmap='jet')
plt.title('cylinderical average')
qx,qy = np.meshgrid(np.linspace(-3,3,100),np.linspace(-3,3,100))
qr = np.sqrt(qx**2+qy**2)
f_sph_ave = np.zeros(qr.shape)
V_ave = np.zeros(qr.shape)
for phi in np.linspace(0,2*np.pi,360):
    for theta in np.linspace(0,np.pi,180):
        qx = qr*np.sin(theta)*np.cos(phi)
        qy = qr*np.sin(theta)*np.sin(phi)
        qz = qr*np.cos(theta)
        f_sph_ave += np.abs(box_form_factor(np.array([qx,qy,qz]),10,3,10,4))*qr**2*np.sin(theta)*\
                        2*np.pi/360*np.pi/180*np.mean(np.diff(qr))
        V_ave += qr**2*np.sin(theta)*\
                        2*np.pi/360*np.pi/180*np.mean(np.diff(qr))
f_sph_ave /= V_ave
        
plt.subplot(133)
plt.imshow(np.log(f_sph_ave+1),vmin=0,vmax=5,cmap='jet')
plt.title('spherical average')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 1.0, 'spherical average')

# %%
plt.subplots()
plt.plot(np.abs(box_form_factor(np.array([qx,qy,qz]),10,3,10,4))[50,:])
plt.plot(f_cly_ave[50,:])
plt.semilogy(f_sph_ave[50,:])

plt.subplots()
qx,qy = np.meshgrid(np.linspace(-3,3,100),np.linspace(-3,3,100))
qz = np.ones(qx.shape)*0
plt.semilogy(np.abs(box_form_factor(np.array([qx,qy,qz]),10,3,10,4))[50,:])
qx,qy = np.meshgrid(np.linspace(-3,3,100),np.linspace(-3,3,100))
qz = np.ones(qx.shape)*2
plt.semilogy(np.abs(box_form_factor(np.array([qx,qy,qz]),10,3,10,4))[50,:])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
#calculate ribbon like form factor
def hkl_coeff(rvec,qvec,h,k,l,pars,func_type='box'):
    '''
    '''
    fhkl = 0+0*1j
    qhkl_vec,qhkl = q_hkl(h,k,l,qvec)
    rot_mat = rotate_matrix(pars['rot_a'],
                            pars['rot_b'],
                            pars['rot_g'])
    #rot_mat = np.linalg.pinv(rot_mat)
    qhkl_vec = np.matmul(rot_mat.T,qhkl_vec)
    for _ in range(len(pars['particle'])):
        
        r = pars['particle_pos'][_][0]*rvec['a']+\
            pars['particle_pos'][_][1]*rvec['b']+\
            pars['particle_pos'][_][2]*rvec['c']
        phase = np.exp(1j*np.dot(r,qhkl_vec))
        if func_type == 'box':
            fhkl += box_form_factor(qhkl_vec,pars['particle_density'][_],
                                pars['la'],pars['lb'],pars['lc'])*phase
        elif func_type == 'sphere':
            fhkl += spherical_form_factor(qhkl_vec,pars['particle_density'][_],
                                pars['r'])*phase
    return fhkl,qhkl

#def sph_ave_form_factor(obj,pars,qr):
#    if obj = 'box':

def structure_factor(qr,h,k,l,pars,sigma,func_type='box'):
    '''
    '''
    a = pars['a']
    b = pars['b']
    c = pars['c']
    alpha = np.radians(pars['alpha'])
    beta  = np.radians(pars['beta'])
    gamma = np.radians(pars['gamma'])
    
    rvec,qvec = vec_cal(a,b,c,alpha,beta,gamma)
    hv,kv,lv = np.meshgrid(np.arange(-h,h+1),np.arange(-k,k+1),np.arange(-l,l+1))
    hkl = np.vstack((hv.flatten(),kv.flatten(),lv.flatten()))
    S = np.zeros((len(qr)))
    for _ in range(hkl.shape[1]):
        fhkl,qhkl = hkl_coeff(rvec,qvec,hkl[0,_],hkl[1,_],hkl[2,_],pars,func_type=func_type) 
        if qhkl > np.max(qr):
            pass
        elif qhkl < 0.001:
            pass
        else:
            S += np.abs(fhkl)**2*gaussian(qr,qhkl,sigma)
    return S/qr**2

def layer_line_factor(qr,h,k,l,pars,sigma):
    '''
    '''
    a = pars['a']
    b = pars['b']
    c = pars['c']
    alpha = np.radians(pars['alpha'])
    beta  = np.radians(pars['beta'])
    gamma = np.radians(pars['gamma'])
    
    rvec,qvec = vec_cal(a,b,c,alpha,beta,gamma)
    # only calculate the h, k index for l layer
    hv,kv,lv = np.meshgrid(np.arange(-h,h+1),np.arange(-k,k+1),np.arange(l,l+1))
    hkl = np.vstack((hv.flatten(),kv.flatten(),lv.flatten()))
    S = np.zeros((len(qr)))
    for _ in range(hkl.shape[1]):
        fhkl,qhkl = hkl_coeff(rvec,qvec,hkl[0,_],hkl[1,_],hkl[2,_],pars)
        Qr_vec = hkl[0,_]*qvec['A']+hkl[1,_]*qvec['B']+hkl[2,_]*qvec['C']
        Qr = np.sqrt(Qr_vec[0]**2+Qr_vec[1]**2)
        if Qr > np.max(qr):
            pass
        else:
            S += np.abs(fhkl)**2*gaussian(qr,Qr,sigma)
    return S/qr

# %%
def dw_factor(q,a,sigma):
    return np.exp(-sigma**2*a**2*q**2)
        
def spherical_ave_form_factor(q,density,r):
    V = 4./3*np.pi*r**3
    return ((3*V*(np.sin(q*r)-q*r*np.cos(q*r))/((q*r)**3))**2)/V

def intensity(x,qr,h,k,l,func_type):
    pars = {}
    bkgd_p = x[0:6]
    dw_a = x[6]
    dw_sigma = x[7]
    scale1 = x[8]
    scale2 = x[9]
    sigma  = x[10]
    pars['a'] = x[11]
    pars['b'] = x[12]
    pars['c'] = x[13]
    pars['alpha'] = x[14]
    pars['beta']  = x[15]
    pars['gamma'] = x[16]
    pars['particle_pos'] = [x[17:20],x[20:23]]
    pars['particle'] = ['particle1','particle2']
    pars['particle_density'] = [10,10]
    pars['r'] = 10
    pars['rot_a'] = 0.
    pars['rot_b'] = 0.
    pars['rot_g'] = 0.
    S = structure_factor(qr,h,k,l,pars,sigma,func_type=func_type)
    F = spherical_ave_form_factor(qr,10,pars['r'])
    bkgd = np.polyval(bkgd_p,qr)
    I = ((1-dw_factor(q,dw_a,dw_sigma))*F+S*dw_factor(q,dw_a,dw_sigma)*scale1)*scale2+bkgd
    return I

# %%
g = np.array([11,1,1,1,1,1,1,1])
gg = [g[0:3],g[3:6]]
gg[0][0]
# Out:
# 11

# %%
#print(box_form_factor.__name__)
#box_form_factor(qvec, density, a, b, c)

#def ave_form_factor(func,pars,qr):
#    if func.__name__ == 'box':
#        f = np.zeros(np.shape(qr))
#        for phi in np.linspace(0,2*np.pi,360):
#            for theta in np.linspace(0,np.pi,180):
#                qx = qr*np.sin(theta)*np.cos(phi)
#                qy = qr*np.sin(theta)*np.sin(phi)
#                qz = qr*np.cos(theta)
#                f += func()

# %%
def call(f):
    def my_f(*args,**kargs):
        print(f(*args,**kargs))
        return f(*args,**kargs)+1
    return my_f

@call
def add(a,b):
    return a+b
add(1,2)
# Out:
# 3
# 4

# %%
ribbon1 = {}
ribbon1.update(a=Ibeta['a'])
ribbon1.update(b=Ibeta['b'])
ribbon1.update(c=Ibeta['c'])
ribbon1.update(alpha=Ibeta['alpha'])
ribbon1.update(beta=Ibeta['beta'])
ribbon1.update(gamma=Ibeta['gamma'])
ribbon1.update(particle = ['particle1','particle2'])
ribbon1.update(particle_density = [10,10])
ribbon1.update(particle_pos = [[0,0,0],[0.5,0.5,0.5]])
ribbon1.update(la=1.)
ribbon1.update(lb=3.9)
ribbon1.update(lc=5.)
ribbon1.update(rot_a = 0.)
ribbon1.update(rot_b = 0.)
ribbon1.update(rot_g = 0.)

ribbon3 = {}
ribbon3.update(a=Ibeta['a'])
ribbon3.update(b=Ibeta['b'])
ribbon3.update(c=Ibeta['c'])
ribbon3.update(alpha=Ibeta['alpha'])
ribbon3.update(beta=Ibeta['beta'])
ribbon3.update(gamma=Ibeta['gamma'])
ribbon3.update(particle = ['particle1','particle2'])
ribbon3.update(particle_density = [10,10])
ribbon3.update(particle_pos = [[0,0,0],[0.5,0.5,0.5]])
ribbon3.update(r=10.)
ribbon3.update(rot_a = 0.)
ribbon3.update(rot_b = 0.)
ribbon3.update(rot_g = 0.)


ribbon2 = {}
ribbon2.update(a=Ialpha1['a'])
ribbon2.update(b=Ialpha1['b'])
ribbon2.update(c=Ialpha1['c'])
ribbon2.update(alpha=Ialpha1['alpha'])
ribbon2.update(beta=Ialpha1['beta'])
ribbon2.update(gamma=Ialpha1['gamma'])
ribbon2.update(particle = ['particle1'])
ribbon2.update(particle_density = [10])
ribbon2.update(particle_pos = [[0,0,0]])
ribbon2.update(la=1.)
ribbon2.update(lb=3.9)
ribbon2.update(lc=5.)
ribbon2.update(rot_a = 0.)
ribbon2.update(rot_b = 0.)
ribbon2.update(rot_g = 43.5)

# %%
# %run -i NanoParticle.py
q = np.linspace(0.01,3,2000)
qr = np.linspace(0.01,3,2000)
sigma = 0.01
h = 5
k = 5
l = 5
R1  = structure_factor(q,h,k,l,ribbon1,sigma)
#R2  = structure_factor(q,h,k,l,ribbon2,sigma)
R2  = structure_factor(q,h,k,l,ribbon3,sigma,func_type='sphere')
#L1 = layer_line_factor(qr,h,k,3,ribbon1,sigma)
#L2 = layer_line_factor(qr,h,k,0,ribbon2,sigma)
# Out:
# NanoParticle.py:64: RuntimeWarning: invalid value encountered in double_scalars
#   return ((3*V*(np.sin(q*r)-q*r*np.cos(q*r))/((q*r)**3))**2)/V

# %%
plt.subplots()
plt.plot(qr,R1/np.max(R1[100:]))
#plt.plot(qr,L1/np.max(L1[100:]))
#plt.plot(qr,S/np.max(S),linestyle='-')
plt.ylim(-0.1,1.1)
#plt.subplots()
plt.plot(qr,R2/np.max(R2[100:]))
#plt.plot(qr,L2/np.max(L2[100:]))
#plt.plot(qr,S1/np.max(S1),linestyle='-')
plt.ylim(-0.1,1.1)
1/1.02*2*np.pi
# Out:
# <img src="data:image/png;base64,..." width="640">
# 6.159985595274104

# %%
np.array([[1,0,0],[0,1,0],[0,0,1]]).T
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
def add(a,b,**kargs):
    if kargs:
        for key,value in kargs.items():
            print('kargs is {0}, value is {1}'.format(key,value))
            return (a+b)+value
    else:
        return (a+b)

def mul_add(fun,time,a,b,):
    res = 0
    for _ in range(time):
        a += 1
        args = (a,b)
        kargs = np.array([a*2])
        res += fun(*args,c=1)
    return res

def 
mul_add(add,3,2,8)
# Out:
# kargs is c, value is 1
# kargs is c, value is 1
# kargs is c, value is 1
# 39

# %%
np.degrees(np.arctan(5.604/(6.658-1.692)))
# Out:
# 48.45415432607491
